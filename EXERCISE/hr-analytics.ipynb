# %% [markdown]
# HR ANALYTICS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
d=pd.read_csv("/home/c1/Documents/Machine_Learning/DATASETS/HR_comma_sep.csv")
d.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
d.sample(5)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 3361                 0.99             0.70               5
# 13616                0.60             0.62               3
# 8094                 0.65             0.60               3
# 4113                 0.64             0.57               5
# 9882                 0.90             0.53               3
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 3361                    195                   3              0     0
# 13616                   238                   4              0     0
# 8094                    148                   2              0     0
# 4113                    149                   3              1     0
# 9882                    167                   3              0     0
#
#        promotion_last_5years        sales  salary
# 3361                       0      support     low
# 13616                      1    marketing  medium
# 8094                       0    technical     low
# 4113                       0  product_mng  medium
# 9882                       0           hr     low

# %%
X=d[[col for col in d.columns if col != 'salary']]
X.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales

# %%
#chainging into numerics values for sales by doing one-hot encoding
X=pd.get_dummies(X,columns=['sales'])
X.sample(5)
#we are getting more colums lets try another apporach
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2576                 0.70             0.53               4
# 1304                 0.89             0.98               4
# 12316                0.43             0.47               2
# 7819                 0.67             0.96               4
# 8045                 0.64             0.83               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 2576                    152                   3              0     0
# 1304                    242                   6              0     1
# 12316                   135                   3              0     1
# 7819                    207                   3              0     0
# 8045                    179                   3              0     0
#
#        promotion_last_5years  sales_IT  sales_RandD  sales_accounting  \
# 2576                       0     False        False             False
# 1304                       0     False        False             False
# 12316                      0     False        False             False
# 7819                       0     False        False             False
# 8045                       0     False        False             False
#
#        sales_hr  sales_management  sales_marketing  sales_product_mng  \
# 2576      False             False            False              False
# 1304      False             False             True              False
# 12316     False             False            False              False
# 7819      False             False            False              False
# 8045       True             False            False              False
#
#        sales_sales  sales_support  sales_technical
# 2576         False          False             True
# 1304         False          False            False
# 12316         True          False            False
# 7819         False          False             True
# 8045         False          False            False

# %%
X=d[[col for col in d.columns if col != 'salary']]
X.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales

# %%
#with the same column lets assign themas 1,2,3,...byusing label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X['sales']=le.fit_transform(X['sales'])
X.head()
#so we got our solution lets focus ontarget i.e -salary
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 2
#       1 #with the same column lets assign themas 1,2,3,...byusing label encoder
# ----> 2 from sklearn.preprocessing import LabelEncoder
#       3 le=LabelEncoder()
#       4 X['sales']=le.fit_transform(X['sales'])
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
#ordinal encoding since they can be order like low<medium<high or  vice versa
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(categories=[['low','medium','high']])
y=d['salary']
#while doing 
y['salary']=oe.fit_transform(y[['salary']])
d['salary']=oe.fit_transform(d[['salary']])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 2
#       1 #ordinal encoding since they can be order like low<medium<high or  vice versa
# ----> 2 from sklearn.preprocessing import OrdinalEncoder
#       3 oe=OrdinalEncoder(categories=[['low','medium','high']])
#       4 y=d['salary']
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
d.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
y=d['salary']
y.head()
# Out:
# 0       low
# 1    medium
# 2    medium
# 3       low
# 4       low
# Name: salary, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# lr=make_pipeline(StandardScaler(),LogisticRegression())
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from sklearn.linear_model import LogisticRegression
#       2 from sklearn.preprocessing import StandardScaler
#       3 from sklearn.pipeline import make_pipeline
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
lr.score(X_test,y_test)
# Out:
# 0.502

# %% [markdown]
# I dont why i got that error while fitting the model and also score is very poor that means the training isnot done preopely /n

# %% [markdown]
# 1.have to do some preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from sklearn.preprocessing import LabelEncoder
#
# ModuleNotFoundError: No module named 'sklearn'
