# %% [markdown]
# HR ANALYTICS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
d=pd.read_csv("/home/c1/Documents/Machine_Learning/DATASETS/HR_comma_sep.csv")
d.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
d.sample(5)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 11064                0.59             0.53               5
# 14593                0.45             0.48               2
# 1033                 0.42             0.56               2
# 11062                0.94             0.95               5
# 5174                 0.80             0.97               5
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 11064                   169                   3              0     0
# 14593                   144                   3              0     1
# 1033                    158                   3              0     1
# 11062                   170                   3              0     0
# 5174                    258                   3              0     0
#
#        promotion_last_5years      sales  salary
# 11064                      0  technical     low
# 14593                      0  marketing  medium
# 1033                       0  technical     low
# 11062                      0    support  medium
# 5174                       0         IT  medium

# %%
X=d[[col for col in d.columns if col != 'salary']]
X.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales

# %%
#chainging into numerics values for sales by doing one-hot encoding
X=pd.get_dummies(X,columns=['sales'])
X.sample(5)
#we are getting more colums lets try another apporach
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 3281                 0.48             0.62               3
# 8161                 0.50             0.46               3
# 5877                 0.69             0.56               3
# 1548                 0.90             0.99               4
# 14545                0.10             0.81               6
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 3281                    200                   3              1     0
# 8161                    165                   3              0     0
# 5877                    183                   4              1     0
# 1548                    259                   6              0     1
# 14545                   290                   4              0     1
#
#        promotion_last_5years  sales_IT  sales_RandD  sales_accounting  \
# 3281                       0     False         True             False
# 8161                       0     False         True             False
# 5877                       0     False         True             False
# 1548                       0     False        False             False
# 14545                      0     False        False              True
#
#        sales_hr  sales_management  sales_marketing  sales_product_mng  \
# 3281      False             False            False              False
# 8161      False             False            False              False
# 5877      False             False            False              False
# 1548      False             False            False              False
# 14545     False             False            False              False
#
#        sales_sales  sales_support  sales_technical
# 3281         False          False            False
# 8161         False          False            False
# 5877         False          False            False
# 1548          True          False            False
# 14545        False          False            False

# %%
X=d[[col for col in d.columns if col != 'salary']]
X.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales

# %%
#with the same column lets assign themas 1,2,3,...byusing label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X['sales']=le.fit_transform(X['sales'])
X.head()
#so we got our solution lets focus ontarget i.e -salary
# Out:
# /tmp/ipykernel_9879/56869604.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['sales']=le.fit_transform(X['sales'])
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales
# 0                   3              0     1                      0      7
# 1                   6              0     1                      0      7
# 2                   4              0     1                      0      7
# 3                   5              0     1                      0      7
# 4                   3              0     1                      0      7

# %%
#ordinal encoding since they can be order like low<medium<high or  vice versa
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(categories=[['low','medium','high']])
y=d['salary']
#while doing 
y['salary']=oe.fit_transform(y[['salary']])
d['salary']=oe.fit_transform(d[['salary']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 6
#       4 y=d['salary']
#       5 #while doing
# ----> 6 y['salary']=oe.fit_transform(y[['salary']])
#       7 d['salary']=oe.fit_transform(d[['salary']])
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1072, in Series.__getitem__(self, key)
#    1069     key = np.asarray(key, dtype=bool)
#    1070     return self._get_rows_with_mask(key)
# -> 1072 return self._get_with(key)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1113, in Series._get_with(self, key)
#    1110         return self.iloc[key]
#    1112 # handle the dup indexing case GH#4246
# -> 1113 return self.loc[key]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1382, in _LocIndexer._getitem_axis(self, key, axis)
#    1379     if hasattr(key, "ndim") and key.ndim > 1:
#    1380         raise ValueError("Cannot index with multidimensional key")
# -> 1382     return self._getitem_iterable(key, axis=axis)
#    1384 # nested tuple slicing
#    1385 if is_nested_tuple(key, labels):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1322, in _LocIndexer._getitem_iterable(self, key, axis)
#    1319 self._validate_key(key, axis)
#    1321 # A collection of keys
# -> 1322 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1323 return self.obj._reindex_with_indexers(
#    1324     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1325 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1520, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1517 ax = self.obj._get_axis(axis)
#    1518 axis_name = self.obj._get_axis_name(axis)
# -> 1520 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1522 return keyarr, indexer
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6175, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     if use_interval_msg:
#    6174         key = list(key)
# -> 6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['salary'], dtype='object')] are in the [index]"

# %%
d.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
y=d['salary']
y.head()
# Out:
# 0       low
# 1    medium
# 2    medium
# 3       low
# 4       low
# Name: salary, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# lr=make_pipeline(StandardScaler(),LogisticRegression())
lr=LogisticRegression(
    C=5.01,
    fit_intercept=False,
    )
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=5.01, fit_intercept=False)

# %%
lr.score(X_test,y_test)
# Out:
# 0.5

# %% [markdown]
# I dont why i got that error while fitting the model and also score is very poor that means the training isnot done preopely /n

# %% [markdown]
# 1.have to do some preprocessing

# %% [markdown]
# MINMAX -SCALER

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train1,X_test1,y_train1,y_test1=train_test_split(X_scaled,y,test_size=0.1)

# %%
lr=LogisticRegression(
    C=1000,)
lr.fit(X_train1,y_train1)
# Out:
# LogisticRegression(C=1000)

# %%
lr.score(X_test1,y_test1)
# Out:
# 0.544
