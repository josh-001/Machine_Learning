# %% [markdown]
# HR ANALYTICS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
d=pd.read_csv("/home/c1/Documents/Machine_Learning/DATASETS/HR_comma_sep.csv")
d.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
d.sample(5)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 10559                0.49             0.50               5
# 10898                0.88             0.85               3
# 7005                 0.82             0.66               4
# 2129                 0.56             0.76               3
# 2565                 0.48             0.67               5
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 10559                   170                   2              0     0
# 10898                   220                   3              0     0
# 7005                    150                   3              0     0
# 2129                    213                   2              1     0
# 2565                    273                   3              0     0
#
#        promotion_last_5years        sales  salary
# 10559                      0        sales  medium
# 10898                      0   management  medium
# ...

# %%
X=d[[col for col in d.columns if col != 'salary']]
X.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales

# %%
#chainging into numerics values for sales by doing one-hot encoding
X=pd.get_dummies(X,columns=['sales'])
X.sample(5)
#we are getting more colums lets try another apporach
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 8769                 0.72             0.68               3
# 14637                0.74             0.92               4
# 9607                 0.97             0.60               3
# 1108                 0.10             0.91               7
# 1656                 0.84             0.85               5
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 8769                    150                   3              1     0
# 14637                   261                   5              0     1
# 9607                    169                   2              1     0
# 1108                    297                   4              0     1
# 1656                    260                   5              0     1
#
#        promotion_last_5years  sales_IT  sales_RandD  sales_accounting  \
# 8769                       0     False        False             False
# ...

# %%
X=d[[col for col in d.columns if col != 'salary']]
X.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales

# %%
#with the same column lets assign themas 1,2,3,...byusing label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X['sales']=le.fit_transform(X['sales'])
X.head()
#so we got our solution lets focus ontarget i.e -salary
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /tmp/ipykernel_17952/56869604.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['sales']=le.fit_transform(X['sales'])
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# ...

# %%
#ordinal encoding since they can be order like low<medium<high or  vice versa
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(categories=[['low','medium','high']])
y=d['salary']
#while doing 
#y['salary']=oe.fit_transform(y[['salary']])
d['salary']=oe.fit_transform(d[['salary']])

# %%
d.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     0.0
# 1     1.0
# 2     1.0
# 3     0.0
# ...

# %%
y=d['salary']
y.head()
# Out:
# 0    0.0
# 1    1.0
# 2    1.0
# 3    0.0
# 4    0.0
# Name: salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# lr=make_pipeline(StandardScaler(),LogisticRegression())
lr=LogisticRegression(
    C=5.01,
    fit_intercept=False,
    )
lr.fit(X_train,y_train)
# Out:
# /home/c1/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=5.01, fit_intercept=False)

# %%
lr.score(X_test,y_test)
# Out:
# 0.4886666666666667

# %% [markdown]
# I dont why i got that error while fitting the model and also score is very poor that means the training isnot done preopely /n

# %% [markdown]
# 1.have to do some preprocessing

# %% [markdown]
# MINMAX -SCALER

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train1,X_test1,y_train1,y_test1=train_test_split(X_scaled,y,test_size=0.1)

# %%
lr=LogisticRegression(
    C=0.00001,)
lr.fit(X_train1,y_train1)
# Out:
# LogisticRegression(C=1e-05)

# %%
lr.score(X_test1,y_test1)
# Out:
# 0.496
